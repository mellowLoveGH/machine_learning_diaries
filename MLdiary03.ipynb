# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
'''Colorization autoencoder
The autoencoder is trained with grayscale images as input
and colored images as output.
Colorization autoencoder can be treated like the opposite
of denoising autoencoder. Instead of removing noise, colorization
adds noise (color) to the grayscale image.
Grayscale Images --> Colorization --> Color Images
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import os

def rgb2gray(rgb):
    """Convert from color image (RGB) to grayscale.
       Source: opencv.org
       grayscale = 0.299*red + 0.587*green + 0.114*blue
    Argument:
        rgb (tensor): rgb image
    Return:
        (tensor): grayscale image
    """
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])


# load the CIFAR10 data
(x_train, _), (x_test, _) = cifar10.load_data()

# input image dimensions
# we assume data format "channels_last"
img_rows = x_train.shape[1]
img_cols = x_train.shape[2]
channels = x_train.shape[3]

# create saved_images folder
imgs_dir = 'saved_images'
save_dir = os.path.join(os.getcwd(), imgs_dir)
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)

# display the 1st 100 input images (color and gray)
imgs = x_test[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test color images (Ground  Truth)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/test_color.png' % imgs_dir)
plt.show()

# convert color train and test images to gray
x_train_gray = rgb2gray(x_train)
x_test_gray = rgb2gray(x_test)

# display grayscale version of test images
imgs = x_test_gray[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test gray images (Input)')
plt.imshow(imgs, interpolation='none', cmap='gray')
plt.savefig('%s/test_gray.png' % imgs_dir)
plt.show()


# normalize output train and test color images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# normalize input train and test grayscale images
x_train_gray = x_train_gray.astype('float32') / 255
x_test_gray = x_test_gray.astype('float32') / 255

# reshape images to row x col x channel for CNN output/validation
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)

# reshape images to row x col x channel for CNN input
x_train_gray = x_train_gray.reshape(x_train_gray.shape[0], img_rows, img_cols, 1)
x_test_gray = x_test_gray.reshape(x_test_gray.shape[0], img_rows, img_cols, 1)

# network parameters
input_shape = (img_rows, img_cols, 1)
batch_size = 32
kernel_size = 3
latent_dim = 256
# encoder/decoder number of CNN layers and filters per layer
layer_filters = [64, 128, 256]

# build the autoencoder model
# first build the encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
# stack of Conv2D(64)-Conv2D(128)-Conv2D(256)
for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=2,
               activation='relu',
               padding='same')(x)

# shape info needed to build decoder model so we don't do hand computation
# the input to the decoder's first Conv2DTranspose will have this shape
# shape is (4, 4, 256) which is processed by the decoder back to (32, 32, 3)
shape = K.int_shape(x)

# generate a latent vector
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)

# instantiate encoder model
encoder = Model(inputs, latent, name='encoder')
encoder.summary()

# build the decoder model
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)

# stack of Conv2DTranspose(256)-Conv2DTranspose(128)-Conv2DTranspose(64)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        strides=2,
                        activation='relu',
                        padding='same')(x)

outputs = Conv2DTranspose(filters=channels,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()

# autoencoder = encoder + decoder
# instantiate autoencoder model
autoencoder = Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()

# prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# reduce learning rate by sqrt(0.1) if the loss does not improve in 5 epochs
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# save weights for future use (e.g. reload parameters w/o training)
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

# Mean Square Error (MSE) loss function, Adam optimizer
autoencoder.compile(loss='mse', optimizer='adam')

# called every epoch
callbacks = [lr_reducer, checkpoint]

# train the autoencoder
autoencoder.fit(x_train_gray,
                x_train,
                validation_data=(x_test_gray, x_test),
                epochs=30,
                batch_size=batch_size,
                callbacks=callbacks)

# predict the autoencoder output from test data
x_decoded = autoencoder.predict(x_test_gray)

# display the 1st 100 colorized images
imgs = x_decoded[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               1048832
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 256)]             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       295040
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 64)        73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 32, 32, 3)         1731
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               1418496
# _________________________________________________________________
# decoder (Functional)         (None, 32, 32, 3)         2013315
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 41s 22ms/step - loss: 0.0235 - val_loss: 0.0113
#
# Epoch 00001: val_loss improved from inf to 0.01129, saving model to /content/saved_models/colorized_ae_model.001.h5
# Epoch 2/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0106 - val_loss: 0.0119
#
# Epoch 00002: val_loss did not improve from 0.01129
# Epoch 3/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0095 - val_loss: 0.0088
#
# Epoch 00003: val_loss improved from 0.01129 to 0.00881, saving model to /content/saved_models/colorized_ae_model.003.h5
# Epoch 4/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0087 - val_loss: 0.0084
#
# Epoch 00004: val_loss improved from 0.00881 to 0.00840, saving model to /content/saved_models/colorized_ae_model.004.h5
# Epoch 5/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0082 - val_loss: 0.0083
#
# Epoch 00005: val_loss improved from 0.00840 to 0.00829, saving model to /content/saved_models/colorized_ae_model.005.h5
# Epoch 6/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0079 - val_loss: 0.0084
#
# Epoch 00006: val_loss did not improve from 0.00829
# Epoch 7/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0077 - val_loss: 0.0080
#
# Epoch 00007: val_loss improved from 0.00829 to 0.00801, saving model to /content/saved_models/colorized_ae_model.007.h5
# Epoch 8/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0074 - val_loss: 0.0079
#
# Epoch 00008: val_loss improved from 0.00801 to 0.00789, saving model to /content/saved_models/colorized_ae_model.008.h5
# Epoch 9/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0071 - val_loss: 0.0077
#
# Epoch 00009: val_loss improved from 0.00789 to 0.00775, saving model to /content/saved_models/colorized_ae_model.009.h5
# Epoch 10/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0069 - val_loss: 0.0082
#
# Epoch 00010: val_loss did not improve from 0.00775
# Epoch 11/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0066 - val_loss: 0.0079
#
# Epoch 00011: val_loss did not improve from 0.00775
# Epoch 12/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0064 - val_loss: 0.0078
#
# Epoch 00012: val_loss did not improve from 0.00775
# Epoch 13/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0061 - val_loss: 0.0078
#
# Epoch 00013: val_loss did not improve from 0.00775
# Epoch 14/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0059 - val_loss: 0.0078
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00014: val_loss did not improve from 0.00775
# Epoch 15/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0052 - val_loss: 0.0075
#
# Epoch 00015: val_loss improved from 0.00775 to 0.00752, saving model to /content/saved_models/colorized_ae_model.015.h5
# Epoch 16/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0049 - val_loss: 0.0076
#
# Epoch 00016: val_loss did not improve from 0.00752
# Epoch 17/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0047 - val_loss: 0.0076
#
# Epoch 00017: val_loss did not improve from 0.00752
# Epoch 18/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0046 - val_loss: 0.0076
#
# Epoch 00018: val_loss did not improve from 0.00752
# Epoch 19/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0045 - val_loss: 0.0078
#
# Epoch 00019: val_loss did not improve from 0.00752
# Epoch 20/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0044 - val_loss: 0.0077
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00020: val_loss did not improve from 0.00752
# Epoch 21/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0041 - val_loss: 0.0077
#
# Epoch 00021: val_loss did not improve from 0.00752
# Epoch 22/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0040 - val_loss: 0.0077
#
# Epoch 00022: val_loss did not improve from 0.00752
# Epoch 23/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0040 - val_loss: 0.0077
#
# Epoch 00023: val_loss did not improve from 0.00752
# Epoch 24/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0039 - val_loss: 0.0079
#
# Epoch 00024: val_loss did not improve from 0.00752
# Epoch 25/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0039 - val_loss: 0.0078
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 00025: val_loss did not improve from 0.00752
# Epoch 26/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0038 - val_loss: 0.0078
#
# Epoch 00026: val_loss did not improve from 0.00752
# Epoch 27/30
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0038 - val_loss: 0.0078
#
# Epoch 00027: val_loss did not improve from 0.00752
# Epoch 28/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0038 - val_loss: 0.0078
#
# Epoch 00028: val_loss did not improve from 0.00752
# Epoch 29/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0038 - val_loss: 0.0078
#
# Epoch 00029: val_loss did not improve from 0.00752
# Epoch 30/30
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0038 - val_loss: 0.0078
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
#
# Epoch 00030: val_loss did not improve from 0.00752

# %%
autoencoder.save('clr_model01.h5')

# %%
# GAN

'''Trains DCGAN on MNIST using Keras
DCGAN is a Generative Adversarial Network (GAN) using CNN.
The generator tries to fool the discriminator by generating fake images.
The discriminator learns to discriminate real from fake images.
The generator + discriminator form an adversarial network.
DCGAN trains the discriminator and adversarial networks alternately.
During training, not only the discriminator learns to distinguish real from
fake images, it also coaches the generator part of the adversarial on how
to improve its ability to generate fake images.
[1] Radford, Alec, Luke Metz, and Soumith Chintala.
"Unsupervised representation learning with deep convolutional
generative adversarial networks." arXiv preprint arXiv:1511.06434 (2015).
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Activation, Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model

import numpy as np
import math
import matplotlib.pyplot as plt
import os
import argparse

# %%
def build_generator(inputs, image_size):
    """Build a Generator Model
    Stack of BN-ReLU-Conv2DTranpose to generate fake images
    Output activation is sigmoid instead of tanh in [1].
    Sigmoid converges easily.
    Arguments:
        inputs (Layer): Input layer of the generator 
            the z-vector)
        image_size (tensor): Target size of one side
            (assuming square image)
    Returns:
        generator (Model): Generator Model
    """
    image_resize = image_size // 4
    # network parameters 
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]

    x = Dense(image_resize * image_resize * layer_filters[0])(inputs)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)

    for filters in layer_filters:
        # first two convolution layers use strides = 2
        # the last two use strides = 1
        if filters > layer_filters[-2]:
            strides = 2
        else:
            strides = 1
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters=filters, kernel_size=kernel_size, strides=strides, padding='same')(x)

    x = Activation('sigmoid')(x)
    generator = Model(inputs, x, name='generator')
    return generator

def build_discriminator(inputs):
    """Build a Discriminator Model
    Stack of LeakyReLU-Conv2D to discriminate real from fake.
    The network does not converge with BN so it is not used here
    unlike in [1] or original paper.
    Arguments:
        inputs (Layer): Input layer of the discriminator (the image)
    Returns:
        discriminator (Model): Discriminator Model
    """
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]

    x = inputs
    for filters in layer_filters:
        # first 3 convolution layers use strides = 2
        # last one uses strides = 1
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same')(x)

    x = Flatten()(x)
    x = Dense(1)(x)
    x = Activation('sigmoid')(x)
    discriminator = Model(inputs, x, name='discriminator')
    return discriminator


def train(models, x_train, params):
    """Train the Discriminator and Adversarial Networks
    Alternately train Discriminator and Adversarial networks by batch.
    Discriminator is trained first with properly real and fake images.
    Adversarial is trained next with fake images pretending to be real
    Generate sample images per save_interval.
    Arguments:
        models (list): Generator, Discriminator, Adversarial models
        x_train (tensor): Train images
        params (list) : Networks parameters
    """
    # the GAN component models
    generator, discriminator, adversarial = models
    # network parameters
    batch_size, latent_size, train_steps, model_name = params
    # the generator image is saved every 500 steps
    save_interval = 500
    # noise vector to see how the generator output evolves during training
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, latent_size])
    # number of elements in train dataset
    train_size = x_train.shape[0]
    for i in range(train_steps):
        # train the discriminator for 1 batch
        # 1 batch of real (label=1.0) and fake images (label=0.0)
        # randomly pick real images from dataset
        rand_indexes = np.random.randint(0, train_size, size=batch_size)
        real_images = x_train[rand_indexes]
        # generate fake images from noise using generator 
        # generate noise using uniform distribution
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        # generate fake images
        fake_images = generator.predict(noise)
        # real + fake images = 1 batch of train data
        x = np.concatenate((real_images, fake_images))
        # label real and fake images
        # real images label is 1.0
        y = np.ones([2 * batch_size, 1])
        # fake images label is 0.0
        y[batch_size:, :] = 0.0
        # train discriminator network, log the loss and accuracy
        loss, acc = discriminator.train_on_batch(x, y)
        log = "%d: [discriminator loss: %f, acc: %f]" % (i, loss, acc)

        # train the adversarial network for 1 batch
        # 1 batch of fake images with label=1.0
        # since the discriminator weights 
        # are frozen in adversarial network
        # only the generator is trained
        # generate noise using uniform distribution
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        # label fake images as real or 1.0
        y = np.ones([batch_size, 1])
        # train the adversarial network 
        # note that unlike in discriminator training, 
        # we do not save the fake images in a variable
        # the fake images go to the discriminator input of the adversarial
        # for classification
        # log the loss and accuracy
        loss, acc = adversarial.train_on_batch(noise, y)
        log = "%s [adversarial loss: %f, acc: %f]" % (log, loss, acc)
        print(log)
        if (i + 1) % save_interval == 0:
            # plot generator images on a periodic basis
            plot_images(generator, noise_input=noise_input, show=False, step=(i + 1), model_name=model_name)
   
    # save the model after training the generator
    # the trained generator can be reloaded for 
    # future MNIST digit generation
    generator.save(model_name + ".h5")

def plot_images(generator, noise_input, show=False, step=0, model_name="gan"):
    """Generate fake images and plot them
    For visualization purposes, generate fake images
    then plot them in a square grid
    Arguments:
        generator (Model): The Generator Model for 
            fake images generation
        noise_input (ndarray): Array of z-vectors
        show (bool): Whether to show plot or not
        step (int): Appended to filename of the save images
        model_name (string): Model name
    """
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "%05d.png" % step)
    images = generator.predict(noise_input)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    rows = int(math.sqrt(noise_input.shape[0]))
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')


def build_and_train_models():
    # load MNIST dataset
    (x_train, _), (_, _) = mnist.load_data()

    # reshape data for CNN as (28, 28, 1) and normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32') / 255

    model_name = "dcgan_mnist"
    # network parameters
    # the latent or z vector is 100-dim
    latent_size = 100
    batch_size = 64
    train_steps = 40000
    lr = 2e-4
    decay = 6e-8
    input_shape = (image_size, image_size, 1)

    # build discriminator model
    inputs = Input(shape=input_shape, name='discriminator_input')
    discriminator = build_discriminator(inputs)
    # [1] or original paper uses Adam, 
    # but discriminator converges easily with RMSprop
    optimizer = RMSprop(lr=lr, decay=decay)
    discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    discriminator.summary()

    # build generator model
    input_shape = (latent_size, )
    inputs = Input(shape=input_shape, name='z_input')
    generator = build_generator(inputs, image_size)
    generator.summary()

    # build adversarial model
    optimizer = RMSprop(lr=lr * 0.5, decay=decay * 0.5)
    # freeze the weights of discriminator during adversarial training
    discriminator.trainable = False
    # adversarial = generator + discriminator
    adversarial = Model(inputs, discriminator(generator(inputs)), name=model_name)
    adversarial.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    adversarial.summary()

    # train discriminator and adversarial networks
    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size, train_steps, model_name)
    train(models, x_train, params)

def test_generator(generator):
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, 100])
    plot_images(generator, noise_input=noise_input, show=True, model_name="test_outputs")

# %%
#!python3 dcgan-mnist-4.2.1.py --generator=dcgan_mnist.h5
build_and_train_models()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 35000: [discriminator loss: 0.513450, acc: 0.710938] [adversarial loss: 1.226524, acc: 0.296875]
# 35001: [discriminator loss: 0.518675, acc: 0.710938] [adversarial loss: 1.732456, acc: 0.078125]
# 35002: [discriminator loss: 0.490932, acc: 0.726562] [adversarial loss: 0.895911, acc: 0.421875]
# 35003: [discriminator loss: 0.528469, acc: 0.726562] [adversarial loss: 1.311194, acc: 0.250000]
# 35004: [discriminator loss: 0.530214, acc: 0.687500] [adversarial loss: 1.275554, acc: 0.187500]
# 35005: [discriminator loss: 0.445150, acc: 0.796875] [adversarial loss: 1.646635, acc: 0.078125]
# 35006: [discriminator loss: 0.463242, acc: 0.796875] [adversarial loss: 1.025525, acc: 0.359375]
# 35007: [discriminator loss: 0.480045, acc: 0.757812] [adversarial loss: 1.452181, acc: 0.203125]
# 35008: [discriminator loss: 0.555236, acc: 0.687500] [adversarial loss: 1.066080, acc: 0.296875]
# 35009: [discriminator loss: 0.533025, acc: 0.757812] [adversarial loss: 1.829870, acc: 0.031250]
# 35010: [discriminator loss: 0.544826, acc: 0.703125] [adversarial loss: 0.768767, acc: 0.578125]
# 35011: [discriminator loss: 0.590586, acc: 0.718750] [adversarial loss: 1.582077, acc: 0.171875]
# 35012: [discriminator loss: 0.446478, acc: 0.742188] [adversarial loss: 1.305818, acc: 0.265625]
# 35013: [discriminator loss: 0.538860, acc: 0.726562] [adversarial loss: 1.579959, acc: 0.156250]
# 35014: [discriminator loss: 0.528508, acc: 0.718750] [adversarial loss: 1.086161, acc: 0.390625]
# 35015: [discriminator loss: 0.546032, acc: 0.718750] [adversarial loss: 1.343662, acc: 0.265625]
# 35016: [discriminator loss: 0.512150, acc: 0.789062] [adversarial loss: 1.326203, acc: 0.218750]
# 35017: [discriminator loss: 0.540677, acc: 0.687500] [adversarial loss: 1.060982, acc: 0.390625]
# 35018: [discriminator loss: 0.508125, acc: 0.734375] [adversarial loss: 1.456573, acc: 0.156250]
# 35019: [discriminator loss: 0.523232, acc: 0.750000] [adversarial loss: 1.343445, acc: 0.265625]
# 35020: [discriminator loss: 0.523612, acc: 0.765625] [adversarial loss: 1.256249, acc: 0.312500]
# 35021: [discriminator loss: 0.536090, acc: 0.718750] [adversarial loss: 0.998394, acc: 0.375000]
# 35022: [discriminator loss: 0.517761, acc: 0.750000] [adversarial loss: 1.490108, acc: 0.140625]
# 35023: [discriminator loss: 0.520988, acc: 0.742188] [adversarial loss: 0.809204, acc: 0.468750]
# 35024: [discriminator loss: 0.576667, acc: 0.679688] [adversarial loss: 1.531328, acc: 0.203125]
# 35025: [discriminator loss: 0.542176, acc: 0.695312] [adversarial loss: 1.066356, acc: 0.312500]
# 35026: [discriminator loss: 0.564794, acc: 0.703125] [adversarial loss: 1.416770, acc: 0.203125]
# 35027: [discriminator loss: 0.511239, acc: 0.781250] [adversarial loss: 1.160675, acc: 0.343750]
# 35028: [discriminator loss: 0.517108, acc: 0.757812] [adversarial loss: 1.280184, acc: 0.250000]
# 35029: [discriminator loss: 0.556685, acc: 0.679688] [adversarial loss: 1.093663, acc: 0.375000]
# 35030: [discriminator loss: 0.524036, acc: 0.750000] [adversarial loss: 1.503913, acc: 0.171875]
# 35031: [discriminator loss: 0.533904, acc: 0.703125] [adversarial loss: 1.302466, acc: 0.250000]
# 35032: [discriminator loss: 0.454001, acc: 0.796875] [adversarial loss: 1.244432, acc: 0.203125]
# 35033: [discriminator loss: 0.506266, acc: 0.765625] [adversarial loss: 1.209257, acc: 0.312500]
# 35034: [discriminator loss: 0.502308, acc: 0.734375] [adversarial loss: 1.692593, acc: 0.140625]
# 35035: [discriminator loss: 0.525859, acc: 0.757812] [adversarial loss: 1.231630, acc: 0.343750]
# 35036: [discriminator loss: 0.549244, acc: 0.703125] [adversarial loss: 1.573835, acc: 0.156250]
# 35037: [discriminator loss: 0.502427, acc: 0.734375] [adversarial loss: 1.274719, acc: 0.250000]
# 35038: [discriminator loss: 0.472753, acc: 0.765625] [adversarial loss: 1.347262, acc: 0.234375]
# 35039: [discriminator loss: 0.543098, acc: 0.695312] [adversarial loss: 0.836167, acc: 0.484375]
# 35040: [discriminator loss: 0.526944, acc: 0.750000] [adversarial loss: 1.862981, acc: 0.093750]
# 35041: [discriminator loss: 0.543385, acc: 0.679688] [adversarial loss: 0.699352, acc: 0.609375]
# 35042: [discriminator loss: 0.519104, acc: 0.742188] [adversarial loss: 1.547584, acc: 0.062500]
# 35043: [discriminator loss: 0.566613, acc: 0.679688] [adversarial loss: 0.828996, acc: 0.515625]
# 35044: [discriminator loss: 0.567758, acc: 0.734375] [adversarial loss: 1.503470, acc: 0.109375]
# 35045: [discriminator loss: 0.470341, acc: 0.789062] [adversarial loss: 1.230541, acc: 0.281250]
# 35046: [discriminator loss: 0.498074, acc: 0.820312] [adversarial loss: 1.295904, acc: 0.234375]
# 35047: [discriminator loss: 0.454350, acc: 0.757812] [adversarial loss: 1.196581, acc: 0.234375]
# 35048: [discriminator loss: 0.464497, acc: 0.773438] [adversarial loss: 1.102763, acc: 0.390625]
# 35049: [discriminator loss: 0.482364, acc: 0.765625] [adversarial loss: 1.474042, acc: 0.218750]
# 35050: [discriminator loss: 0.575924, acc: 0.679688] [adversarial loss: 0.853617, acc: 0.484375]
# 35051: [discriminator loss: 0.510813, acc: 0.773438] [adversarial loss: 1.235870, acc: 0.234375]
# 35052: [discriminator loss: 0.558812, acc: 0.703125] [adversarial loss: 1.635392, acc: 0.140625]
# 35053: [discriminator loss: 0.481110, acc: 0.734375] [adversarial loss: 0.886839, acc: 0.484375]
# 35054: [discriminator loss: 0.547328, acc: 0.710938] [adversarial loss: 1.356189, acc: 0.187500]
# 35055: [discriminator loss: 0.528781, acc: 0.726562] [adversarial loss: 0.968349, acc: 0.468750]
# 35056: [discriminator loss: 0.505471, acc: 0.750000] [adversarial loss: 1.465371, acc: 0.093750]
# 35057: [discriminator loss: 0.455294, acc: 0.789062] [adversarial loss: 1.223276, acc: 0.234375]
# 35058: [discriminator loss: 0.559518, acc: 0.703125] [adversarial loss: 1.369208, acc: 0.234375]
# 35059: [discriminator loss: 0.497490, acc: 0.750000] [adversarial loss: 1.056206, acc: 0.375000]
# 35060: [discriminator loss: 0.511424, acc: 0.734375] [adversarial loss: 1.434687, acc: 0.203125]
# 35061: [discriminator loss: 0.539883, acc: 0.671875] [adversarial loss: 1.313687, acc: 0.265625]
# 35062: [discriminator loss: 0.527248, acc: 0.750000] [adversarial loss: 1.575706, acc: 0.156250]
# 35063: [discriminator loss: 0.488605, acc: 0.765625] [adversarial loss: 1.404448, acc: 0.156250]
# 35064: [discriminator loss: 0.470458, acc: 0.757812] [adversarial loss: 1.452326, acc: 0.203125]
# 35065: [discriminator loss: 0.485651, acc: 0.726562] [adversarial loss: 1.225371, acc: 0.281250]
# 35066: [discriminator loss: 0.513734, acc: 0.734375] [adversarial loss: 1.940617, acc: 0.093750]
# 35067: [discriminator loss: 0.607841, acc: 0.687500] [adversarial loss: 0.973314, acc: 0.437500]
# 35068: [discriminator loss: 0.572606, acc: 0.710938] [adversarial loss: 1.763807, acc: 0.062500]
# 35069: [discriminator loss: 0.516893, acc: 0.679688] [adversarial loss: 1.094938, acc: 0.390625]
# 35070: [discriminator loss: 0.537221, acc: 0.734375] [adversarial loss: 1.623738, acc: 0.140625]
# 35071: [discriminator loss: 0.608934, acc: 0.664062] [adversarial loss: 1.031982, acc: 0.296875]
# 35072: [discriminator loss: 0.560341, acc: 0.734375] [adversarial loss: 1.777033, acc: 0.109375]
# 35073: [discriminator loss: 0.439778, acc: 0.828125] [adversarial loss: 1.270087, acc: 0.218750]
# 35074: [discriminator loss: 0.490712, acc: 0.773438] [adversarial loss: 1.955531, acc: 0.062500]
# 35075: [discriminator loss: 0.485601, acc: 0.757812] [adversarial loss: 1.320185, acc: 0.234375]
# 35076: [discriminator loss: 0.553692, acc: 0.671875] [adversarial loss: 1.506962, acc: 0.125000]
# 35077: [discriminator loss: 0.497225, acc: 0.750000] [adversarial loss: 1.096058, acc: 0.328125]
# 35078: [discriminator loss: 0.475082, acc: 0.773438] [adversarial loss: 1.402958, acc: 0.203125]
# 35079: [discriminator loss: 0.526043, acc: 0.710938] [adversarial loss: 1.556663, acc: 0.156250]
# 35080: [discriminator loss: 0.488100, acc: 0.710938] [adversarial loss: 1.357878, acc: 0.156250]
# 35081: [discriminator loss: 0.464286, acc: 0.765625] [adversarial loss: 1.165241, acc: 0.375000]
# 35082: [discriminator loss: 0.491945, acc: 0.710938] [adversarial loss: 1.349192, acc: 0.281250]
# 35083: [discriminator loss: 0.549172, acc: 0.726562] [adversarial loss: 1.400351, acc: 0.250000]
# 35084: [discriminator loss: 0.427904, acc: 0.765625] [adversarial loss: 0.976415, acc: 0.468750]
# 35085: [discriminator loss: 0.480371, acc: 0.757812] [adversarial loss: 1.245505, acc: 0.328125]
# 35086: [discriminator loss: 0.542902, acc: 0.750000] [adversarial loss: 0.970147, acc: 0.468750]
# 35087: [discriminator loss: 0.514349, acc: 0.742188] [adversarial loss: 2.001215, acc: 0.062500]
# 35088: [discriminator loss: 0.539815, acc: 0.695312] [adversarial loss: 0.943955, acc: 0.484375]
# 35089: [discriminator loss: 0.553966, acc: 0.679688] [adversarial loss: 1.799326, acc: 0.156250]
# 35090: [discriminator loss: 0.546965, acc: 0.703125] [adversarial loss: 0.920983, acc: 0.468750]
# 35091: [discriminator loss: 0.585508, acc: 0.718750] [adversarial loss: 1.484416, acc: 0.234375]
# 35092: [discriminator loss: 0.574907, acc: 0.679688] [adversarial loss: 0.880671, acc: 0.375000]
# 35093: [discriminator loss: 0.537737, acc: 0.765625] [adversarial loss: 1.723995, acc: 0.140625]
# 35094: [discriminator loss: 0.479918, acc: 0.750000] [adversarial loss: 1.197702, acc: 0.328125]
# 35095: [discriminator loss: 0.438099, acc: 0.789062] [adversarial loss: 1.343462, acc: 0.265625]
# 35096: [discriminator loss: 0.530955, acc: 0.734375] [adversarial loss: 1.513966, acc: 0.187500]
# 35097: [discriminator loss: 0.563043, acc: 0.695312] [adversarial loss: 1.279484, acc: 0.234375]
# 35098: [discriminator loss: 0.431194, acc: 0.804688] [adversarial loss: 1.530026, acc: 0.140625]
# 35099: [discriminator loss: 0.447053, acc: 0.757812] [adversarial loss: 1.237083, acc: 0.281250]
# 35100: [discriminator loss: 0.457576, acc: 0.835938] [adversarial loss: 1.124004, acc: 0.234375]
# 35101: [discriminator loss: 0.507593, acc: 0.757812] [adversarial loss: 1.396975, acc: 0.187500]
# 35102: [discriminator loss: 0.466335, acc: 0.789062] [adversarial loss: 1.004148, acc: 0.375000]
# 35103: [discriminator loss: 0.482352, acc: 0.796875] [adversarial loss: 1.533866, acc: 0.093750]
# 35104: [discriminator loss: 0.518586, acc: 0.710938] [adversarial loss: 0.792593, acc: 0.468750]
# 35105: [discriminator loss: 0.593894, acc: 0.695312] [adversarial loss: 1.860491, acc: 0.109375]
# 35106: [discriminator loss: 0.524390, acc: 0.703125] [adversarial loss: 0.969488, acc: 0.296875]
# 35107: [discriminator loss: 0.500487, acc: 0.773438] [adversarial loss: 1.547334, acc: 0.093750]
# 35108: [discriminator loss: 0.476668, acc: 0.773438] [adversarial loss: 1.197356, acc: 0.296875]
# 35109: [discriminator loss: 0.528679, acc: 0.718750] [adversarial loss: 1.463206, acc: 0.187500]
# 35110: [discriminator loss: 0.427887, acc: 0.781250] [adversarial loss: 1.215653, acc: 0.328125]
# 35111: [discriminator loss: 0.584792, acc: 0.679688] [adversarial loss: 1.486596, acc: 0.156250]
# 35112: [discriminator loss: 0.502128, acc: 0.742188] [adversarial loss: 0.967793, acc: 0.468750]
# 35113: [discriminator loss: 0.543491, acc: 0.695312] [adversarial loss: 1.630216, acc: 0.156250]
# 35114: [discriminator loss: 0.428018, acc: 0.820312] [adversarial loss: 1.421447, acc: 0.171875]
# 35115: [discriminator loss: 0.482295, acc: 0.750000] [adversarial loss: 0.931143, acc: 0.421875]
# 35116: [discriminator loss: 0.590531, acc: 0.703125] [adversarial loss: 1.503985, acc: 0.109375]
# 35117: [discriminator loss: 0.542117, acc: 0.734375] [adversarial loss: 1.175912, acc: 0.343750]
# 35118: [discriminator loss: 0.546909, acc: 0.718750] [adversarial loss: 1.714343, acc: 0.109375]
# 35119: [discriminator loss: 0.505300, acc: 0.757812] [adversarial loss: 1.105436, acc: 0.390625]
# 35120: [discriminator loss: 0.525211, acc: 0.726562] [adversarial loss: 1.442567, acc: 0.140625]
# 35121: [discriminator loss: 0.508858, acc: 0.703125] [adversarial loss: 1.164704, acc: 0.234375]
# 35122: [discriminator loss: 0.529433, acc: 0.718750] [adversarial loss: 1.576576, acc: 0.125000]
# 35123: [discriminator loss: 0.539530, acc: 0.726562] [adversarial loss: 1.125569, acc: 0.296875]
# 35124: [discriminator loss: 0.636682, acc: 0.664062] [adversarial loss: 1.644537, acc: 0.109375]
# 35125: [discriminator loss: 0.562666, acc: 0.679688] [adversarial loss: 1.086447, acc: 0.312500]
# 35126: [discriminator loss: 0.482623, acc: 0.796875] [adversarial loss: 1.829162, acc: 0.031250]
# 35127: [discriminator loss: 0.543446, acc: 0.703125] [adversarial loss: 1.123804, acc: 0.359375]
# 35128: [discriminator loss: 0.563953, acc: 0.695312] [adversarial loss: 1.528334, acc: 0.187500]
# 35129: [discriminator loss: 0.544771, acc: 0.726562] [adversarial loss: 0.973207, acc: 0.484375]
# 35130: [discriminator loss: 0.526216, acc: 0.757812] [adversarial loss: 1.578895, acc: 0.187500]
# 35131: [discriminator loss: 0.514554, acc: 0.695312] [adversarial loss: 0.932913, acc: 0.421875]
# 35132: [discriminator loss: 0.539381, acc: 0.726562] [adversarial loss: 1.205904, acc: 0.296875]
# 35133: [discriminator loss: 0.566068, acc: 0.640625] [adversarial loss: 0.777625, acc: 0.546875]
# 35134: [discriminator loss: 0.496472, acc: 0.773438] [adversarial loss: 1.781238, acc: 0.031250]
# 35135: [discriminator loss: 0.652469, acc: 0.625000] [adversarial loss: 0.891818, acc: 0.515625]
# 35136: [discriminator loss: 0.628022, acc: 0.640625] [adversarial loss: 1.663252, acc: 0.109375]
# 35137: [discriminator loss: 0.586489, acc: 0.671875] [adversarial loss: 0.933411, acc: 0.437500]
# 35138: [discriminator loss: 0.552777, acc: 0.687500] [adversarial loss: 1.504158, acc: 0.078125]
# 35139: [discriminator loss: 0.476231, acc: 0.804688] [adversarial loss: 1.175480, acc: 0.203125]
# 35140: [discriminator loss: 0.515106, acc: 0.695312] [adversarial loss: 1.206099, acc: 0.187500]
# 35141: [discriminator loss: 0.495930, acc: 0.718750] [adversarial loss: 1.219645, acc: 0.218750]
# 35142: [discriminator loss: 0.588050, acc: 0.734375] [adversarial loss: 1.809669, acc: 0.062500]
# 35143: [discriminator loss: 0.513751, acc: 0.710938] [adversarial loss: 0.964532, acc: 0.531250]
# 35144: [discriminator loss: 0.553748, acc: 0.703125] [adversarial loss: 1.466164, acc: 0.156250]
# 35145: [discriminator loss: 0.552601, acc: 0.718750] [adversarial loss: 0.934413, acc: 0.468750]
# 35146: [discriminator loss: 0.548296, acc: 0.671875] [adversarial loss: 1.386372, acc: 0.140625]
# 35147: [discriminator loss: 0.488989, acc: 0.757812] [adversarial loss: 0.904052, acc: 0.421875]
# 35148: [discriminator loss: 0.499723, acc: 0.757812] [adversarial loss: 1.635394, acc: 0.109375]
# 35149: [discriminator loss: 0.485049, acc: 0.773438] [adversarial loss: 0.955435, acc: 0.406250]
# 35150: [discriminator loss: 0.529354, acc: 0.734375] [adversarial loss: 1.772568, acc: 0.062500]
# 35151: [discriminator loss: 0.543690, acc: 0.671875] [adversarial loss: 0.971383, acc: 0.406250]
# 35152: [discriminator loss: 0.565860, acc: 0.718750] [adversarial loss: 1.693194, acc: 0.093750]
# 35153: [discriminator loss: 0.499329, acc: 0.726562] [adversarial loss: 0.895334, acc: 0.453125]
# 35154: [discriminator loss: 0.571386, acc: 0.726562] [adversarial loss: 1.445855, acc: 0.234375]
# 35155: [discriminator loss: 0.598691, acc: 0.679688] [adversarial loss: 0.993778, acc: 0.484375]
# 35156: [discriminator loss: 0.550469, acc: 0.750000] [adversarial loss: 1.446506, acc: 0.187500]
# 35157: [discriminator loss: 0.445554, acc: 0.812500] [adversarial loss: 1.309504, acc: 0.218750]
# 35158: [discriminator loss: 0.489525, acc: 0.773438] [adversarial loss: 1.381079, acc: 0.187500]
# 35159: [discriminator loss: 0.468187, acc: 0.796875] [adversarial loss: 1.455930, acc: 0.187500]
# 35160: [discriminator loss: 0.518081, acc: 0.734375] [adversarial loss: 1.383901, acc: 0.187500]
# 35161: [discriminator loss: 0.539626, acc: 0.734375] [adversarial loss: 1.185739, acc: 0.328125]
# 35162: [discriminator loss: 0.494307, acc: 0.750000] [adversarial loss: 1.340946, acc: 0.156250]
# 35163: [discriminator loss: 0.498577, acc: 0.734375] [adversarial loss: 1.498788, acc: 0.156250]
# 35164: [discriminator loss: 0.462316, acc: 0.773438] [adversarial loss: 1.802962, acc: 0.156250]
# 35165: [discriminator loss: 0.477955, acc: 0.781250] [adversarial loss: 1.305487, acc: 0.265625]
# 35166: [discriminator loss: 0.536411, acc: 0.695312] [adversarial loss: 1.531340, acc: 0.203125]
# 35167: [discriminator loss: 0.482226, acc: 0.750000] [adversarial loss: 1.268099, acc: 0.281250]
# 35168: [discriminator loss: 0.541750, acc: 0.695312] [adversarial loss: 1.754944, acc: 0.140625]
# 35169: [discriminator loss: 0.517629, acc: 0.734375] [adversarial loss: 1.024597, acc: 0.406250]
# 35170: [discriminator loss: 0.571485, acc: 0.695312] [adversarial loss: 1.965361, acc: 0.031250]
# 35171: [discriminator loss: 0.409743, acc: 0.804688] [adversarial loss: 0.779502, acc: 0.562500]
# 35172: [discriminator loss: 0.575488, acc: 0.679688] [adversarial loss: 1.742925, acc: 0.046875]
# 35173: [discriminator loss: 0.492727, acc: 0.757812] [adversarial loss: 1.082614, acc: 0.390625]
# 35174: [discriminator loss: 0.551012, acc: 0.703125] [adversarial loss: 1.976278, acc: 0.031250]
# 35175: [discriminator loss: 0.577717, acc: 0.703125] [adversarial loss: 0.782939, acc: 0.562500]
# 35176: [discriminator loss: 0.574260, acc: 0.671875] [adversarial loss: 1.569454, acc: 0.109375]
# 35177: [discriminator loss: 0.530724, acc: 0.703125] [adversarial loss: 1.143540, acc: 0.281250]
# 35178: [discriminator loss: 0.522187, acc: 0.734375] [adversarial loss: 1.393492, acc: 0.187500]
# 35179: [discriminator loss: 0.474325, acc: 0.796875] [adversarial loss: 1.282476, acc: 0.125000]
# 35180: [discriminator loss: 0.505043, acc: 0.726562] [adversarial loss: 1.124060, acc: 0.265625]
# 35181: [discriminator loss: 0.461940, acc: 0.796875] [adversarial loss: 1.547083, acc: 0.140625]
# 35182: [discriminator loss: 0.519675, acc: 0.679688] [adversarial loss: 0.878537, acc: 0.500000]
# 35183: [discriminator loss: 0.505742, acc: 0.710938] [adversarial loss: 1.376342, acc: 0.171875]
# 35184: [discriminator loss: 0.542468, acc: 0.710938] [adversarial loss: 0.919662, acc: 0.453125]
# 35185: [discriminator loss: 0.575157, acc: 0.671875] [adversarial loss: 1.924361, acc: 0.078125]
# 35186: [discriminator loss: 0.581381, acc: 0.679688] [adversarial loss: 0.954194, acc: 0.484375]
# 35187: [discriminator loss: 0.519345, acc: 0.726562] [adversarial loss: 1.300494, acc: 0.265625]
# 35188: [discriminator loss: 0.474825, acc: 0.781250] [adversarial loss: 1.255104, acc: 0.265625]
# 35189: [discriminator loss: 0.436352, acc: 0.812500] [adversarial loss: 1.174932, acc: 0.375000]
# 35190: [discriminator loss: 0.463038, acc: 0.828125] [adversarial loss: 1.152688, acc: 0.203125]
# 35191: [discriminator loss: 0.490125, acc: 0.773438] [adversarial loss: 1.237847, acc: 0.281250]
# 35192: [discriminator loss: 0.425073, acc: 0.851562] [adversarial loss: 1.317175, acc: 0.156250]
# 35193: [discriminator loss: 0.473890, acc: 0.773438] [adversarial loss: 1.172805, acc: 0.328125]
# 35194: [discriminator loss: 0.564531, acc: 0.726562] [adversarial loss: 1.440188, acc: 0.218750]
# 35195: [discriminator loss: 0.451815, acc: 0.796875] [adversarial loss: 1.037490, acc: 0.312500]
# 35196: [discriminator loss: 0.599243, acc: 0.718750] [adversarial loss: 1.849512, acc: 0.140625]
# 35197: [discriminator loss: 0.554199, acc: 0.695312] [adversarial loss: 0.883405, acc: 0.531250]
# 35198: [discriminator loss: 0.544217, acc: 0.703125] [adversarial loss: 1.812512, acc: 0.140625]
# 35199: [discriminator loss: 0.540833, acc: 0.726562] [adversarial loss: 1.117023, acc: 0.281250]
# 35200: [discriminator loss: 0.571164, acc: 0.718750] [adversarial loss: 1.520599, acc: 0.140625]
# 35201: [discriminator loss: 0.496055, acc: 0.773438] [adversarial loss: 1.453271, acc: 0.203125]
# 35202: [discriminator loss: 0.520725, acc: 0.757812] [adversarial loss: 1.201268, acc: 0.281250]
# 35203: [discriminator loss: 0.470559, acc: 0.757812] [adversarial loss: 1.434752, acc: 0.125000]
# 35204: [discriminator loss: 0.509308, acc: 0.789062] [adversarial loss: 1.346888, acc: 0.250000]
# 35205: [discriminator loss: 0.585095, acc: 0.687500] [adversarial loss: 1.559801, acc: 0.171875]
# 35206: [discriminator loss: 0.459469, acc: 0.773438] [adversarial loss: 1.238864, acc: 0.328125]
# 35207: [discriminator loss: 0.506358, acc: 0.765625] [adversarial loss: 1.252099, acc: 0.312500]
# 35208: [discriminator loss: 0.500111, acc: 0.781250] [adversarial loss: 1.424102, acc: 0.234375]
# 35209: [discriminator loss: 0.558502, acc: 0.687500] [adversarial loss: 0.706124, acc: 0.656250]
# 35210: [discriminator loss: 0.568404, acc: 0.718750] [adversarial loss: 2.119559, acc: 0.015625]
# 35211: [discriminator loss: 0.564159, acc: 0.710938] [adversarial loss: 1.079877, acc: 0.328125]
# 35212: [discriminator loss: 0.521408, acc: 0.718750] [adversarial loss: 1.344907, acc: 0.250000]
# 35213: [discriminator loss: 0.471981, acc: 0.796875] [adversarial loss: 1.630924, acc: 0.171875]
# 35214: [discriminator loss: 0.564932, acc: 0.718750] [adversarial loss: 1.155367, acc: 0.281250]
# 35215: [discriminator loss: 0.521790, acc: 0.726562] [adversarial loss: 1.552330, acc: 0.218750]
# 35216: [discriminator loss: 0.543846, acc: 0.703125] [adversarial loss: 1.187937, acc: 0.296875]
# 35217: [discriminator loss: 0.544588, acc: 0.742188] [adversarial loss: 1.417866, acc: 0.187500]
# 35218: [discriminator loss: 0.551096, acc: 0.718750] [adversarial loss: 1.255308, acc: 0.343750]
# 35219: [discriminator loss: 0.512530, acc: 0.718750] [adversarial loss: 1.173990, acc: 0.359375]
# 35220: [discriminator loss: 0.479237, acc: 0.781250] [adversarial loss: 1.326964, acc: 0.296875]
# 35221: [discriminator loss: 0.500958, acc: 0.734375] [adversarial loss: 1.195526, acc: 0.218750]
# 35222: [discriminator loss: 0.488788, acc: 0.765625] [adversarial loss: 1.301985, acc: 0.234375]
# 35223: [discriminator loss: 0.501752, acc: 0.781250] [adversarial loss: 1.025202, acc: 0.328125]
# 35224: [discriminator loss: 0.523302, acc: 0.726562] [adversarial loss: 1.614050, acc: 0.093750]
# 35225: [discriminator loss: 0.543570, acc: 0.726562] [adversarial loss: 0.824390, acc: 0.453125]
# 35226: [discriminator loss: 0.562386, acc: 0.718750] [adversarial loss: 1.604611, acc: 0.062500]
# 35227: [discriminator loss: 0.548951, acc: 0.726562] [adversarial loss: 0.870570, acc: 0.515625]
# 35228: [discriminator loss: 0.474929, acc: 0.726562] [adversarial loss: 1.552836, acc: 0.125000]
# 35229: [discriminator loss: 0.486362, acc: 0.750000] [adversarial loss: 0.866757, acc: 0.453125]
# 35230: [discriminator loss: 0.579828, acc: 0.695312] [adversarial loss: 1.494739, acc: 0.125000]
# 35231: [discriminator loss: 0.536350, acc: 0.742188] [adversarial loss: 0.852348, acc: 0.562500]
# 35232: [discriminator loss: 0.503744, acc: 0.726562] [adversarial loss: 1.535127, acc: 0.125000]
# 35233: [discriminator loss: 0.525975, acc: 0.734375] [adversarial loss: 0.801668, acc: 0.515625]
# 35234: [discriminator loss: 0.509374, acc: 0.757812] [adversarial loss: 1.358135, acc: 0.250000]
# 35235: [discriminator loss: 0.378381, acc: 0.835938] [adversarial loss: 0.875809, acc: 0.484375]
# 35236: [discriminator loss: 0.441693, acc: 0.820312] [adversarial loss: 1.384681, acc: 0.250000]
# 35237: [discriminator loss: 0.509157, acc: 0.773438] [adversarial loss: 1.241206, acc: 0.328125]
# 35238: [discriminator loss: 0.572602, acc: 0.679688] [adversarial loss: 1.570184, acc: 0.109375]
# 35239: [discriminator loss: 0.530262, acc: 0.742188] [adversarial loss: 1.108091, acc: 0.328125]
# 35240: [discriminator loss: 0.476451, acc: 0.742188] [adversarial loss: 1.380442, acc: 0.187500]
# 35241: [discriminator loss: 0.502860, acc: 0.718750] [adversarial loss: 1.355247, acc: 0.203125]
# 35242: [discriminator loss: 0.590370, acc: 0.710938] [adversarial loss: 1.271341, acc: 0.250000]
# 35243: [discriminator loss: 0.515933, acc: 0.750000] [adversarial loss: 1.101606, acc: 0.328125]
# 35244: [discriminator loss: 0.542381, acc: 0.734375] [adversarial loss: 1.743018, acc: 0.109375]
# 35245: [discriminator loss: 0.545984, acc: 0.671875] [adversarial loss: 1.086095, acc: 0.359375]
# 35246: [discriminator loss: 0.522298, acc: 0.710938] [adversarial loss: 0.844132, acc: 0.406250]
# 35247: [discriminator loss: 0.523103, acc: 0.765625] [adversarial loss: 1.453370, acc: 0.171875]
# 35248: [discriminator loss: 0.527128, acc: 0.718750] [adversarial loss: 0.884431, acc: 0.515625]
# 35249: [discriminator loss: 0.537245, acc: 0.718750] [adversarial loss: 2.141127, acc: 0.062500]
# 35250: [discriminator loss: 0.568631, acc: 0.710938] [adversarial loss: 0.975388, acc: 0.390625]
# 35251: [discriminator loss: 0.477728, acc: 0.742188] [adversarial loss: 1.683519, acc: 0.140625]
# 35252: [discriminator loss: 0.520000, acc: 0.718750] [adversarial loss: 1.057697, acc: 0.390625]
# 35253: [discriminator loss: 0.557583, acc: 0.710938] [adversarial loss: 1.520960, acc: 0.156250]
# 35254: [discriminator loss: 0.450331, acc: 0.796875] [adversarial loss: 1.223887, acc: 0.250000]
# 35255: [discriminator loss: 0.475121, acc: 0.773438] [adversarial loss: 1.261140, acc: 0.296875]
# 35256: [discriminator loss: 0.462682, acc: 0.781250] [adversarial loss: 1.301258, acc: 0.234375]
# 35257: [discriminator loss: 0.511905, acc: 0.789062] [adversarial loss: 1.418721, acc: 0.171875]
# 35258: [discriminator loss: 0.550663, acc: 0.687500] [adversarial loss: 1.239164, acc: 0.296875]
# 35259: [discriminator loss: 0.490993, acc: 0.765625] [adversarial loss: 1.521083, acc: 0.203125]
# 35260: [discriminator loss: 0.548533, acc: 0.718750] [adversarial loss: 1.053881, acc: 0.453125]
# 35261: [discriminator loss: 0.525346, acc: 0.742188] [adversarial loss: 1.544911, acc: 0.203125]
# 35262: [discriminator loss: 0.552950, acc: 0.765625] [adversarial loss: 0.983959, acc: 0.437500]
# 35263: [discriminator loss: 0.533622, acc: 0.750000] [adversarial loss: 1.700537, acc: 0.078125]
# 35264: [discriminator loss: 0.506491, acc: 0.734375] [adversarial loss: 1.037796, acc: 0.343750]
# 35265: [discriminator loss: 0.502816, acc: 0.757812] [adversarial loss: 1.438773, acc: 0.187500]
# 35266: [discriminator loss: 0.533709, acc: 0.734375] [adversarial loss: 1.427569, acc: 0.234375]
# 35267: [discriminator loss: 0.488734, acc: 0.750000] [adversarial loss: 1.270185, acc: 0.265625]
# 35268: [discriminator loss: 0.419763, acc: 0.828125] [adversarial loss: 0.973848, acc: 0.375000]
# 35269: [discriminator loss: 0.506947, acc: 0.734375] [adversarial loss: 1.294010, acc: 0.328125]
# 35270: [discriminator loss: 0.500526, acc: 0.757812] [adversarial loss: 1.298681, acc: 0.250000]
# 35271: [discriminator loss: 0.483656, acc: 0.804688] [adversarial loss: 1.101084, acc: 0.328125]
# 35272: [discriminator loss: 0.493247, acc: 0.773438] [adversarial loss: 1.617194, acc: 0.140625]
# 35273: [discriminator loss: 0.490514, acc: 0.757812] [adversarial loss: 0.907412, acc: 0.421875]
# 35274: [discriminator loss: 0.490358, acc: 0.742188] [adversarial loss: 1.813999, acc: 0.109375]
# 35275: [discriminator loss: 0.506398, acc: 0.742188] [adversarial loss: 0.879601, acc: 0.546875]
# 35276: [discriminator loss: 0.626163, acc: 0.695312] [adversarial loss: 1.541930, acc: 0.156250]
# 35277: [discriminator loss: 0.562837, acc: 0.703125] [adversarial loss: 1.035684, acc: 0.359375]
# 35278: [discriminator loss: 0.457351, acc: 0.789062] [adversarial loss: 1.312180, acc: 0.218750]
# 35279: [discriminator loss: 0.455478, acc: 0.789062] [adversarial loss: 1.185455, acc: 0.265625]
# 35280: [discriminator loss: 0.467673, acc: 0.796875] [adversarial loss: 1.418437, acc: 0.187500]
# 35281: [discriminator loss: 0.477243, acc: 0.734375] [adversarial loss: 1.175157, acc: 0.359375]
# 35282: [discriminator loss: 0.558211, acc: 0.710938] [adversarial loss: 1.637847, acc: 0.109375]
# 35283: [discriminator loss: 0.510590, acc: 0.750000] [adversarial loss: 1.036535, acc: 0.359375]
# 35284: [discriminator loss: 0.503310, acc: 0.757812] [adversarial loss: 1.475906, acc: 0.234375]
# 35285: [discriminator loss: 0.475174, acc: 0.789062] [adversarial loss: 0.737581, acc: 0.515625]
# 35286: [discriminator loss: 0.514772, acc: 0.765625] [adversarial loss: 1.087653, acc: 0.375000]
# 35287: [discriminator loss: 0.459610, acc: 0.757812] [adversarial loss: 0.706814, acc: 0.562500]
# 35288: [discriminator loss: 0.540205, acc: 0.757812] [adversarial loss: 1.268293, acc: 0.265625]
# 35289: [discriminator loss: 0.410019, acc: 0.773438] [adversarial loss: 0.862852, acc: 0.546875]
# 35290: [discriminator loss: 0.508841, acc: 0.765625] [adversarial loss: 1.141075, acc: 0.390625]
# 35291: [discriminator loss: 0.446754, acc: 0.820312] [adversarial loss: 0.914192, acc: 0.453125]
# 35292: [discriminator loss: 0.505430, acc: 0.726562] [adversarial loss: 1.120645, acc: 0.343750]
# 35293: [discriminator loss: 0.491262, acc: 0.726562] [adversarial loss: 1.088528, acc: 0.312500]
# 35294: [discriminator loss: 0.513649, acc: 0.687500] [adversarial loss: 1.263676, acc: 0.250000]
# 35295: [discriminator loss: 0.522728, acc: 0.757812] [adversarial loss: 1.519959, acc: 0.171875]
# 35296: [discriminator loss: 0.484240, acc: 0.757812] [adversarial loss: 1.330073, acc: 0.265625]
# 35297: [discriminator loss: 0.419440, acc: 0.804688] [adversarial loss: 1.261118, acc: 0.250000]
# 35298: [discriminator loss: 0.509594, acc: 0.734375] [adversarial loss: 1.034696, acc: 0.375000]
# 35299: [discriminator loss: 0.551927, acc: 0.718750] [adversarial loss: 1.297447, acc: 0.296875]
# 35300: [discriminator loss: 0.483699, acc: 0.750000] [adversarial loss: 1.347191, acc: 0.281250]
# 35301: [discriminator loss: 0.595118, acc: 0.679688] [adversarial loss: 1.278613, acc: 0.234375]
# 35302: [discriminator loss: 0.466773, acc: 0.796875] [adversarial loss: 1.527281, acc: 0.140625]
# 35303: [discriminator loss: 0.405385, acc: 0.812500] [adversarial loss: 1.183954, acc: 0.281250]
# 35304: [discriminator loss: 0.519171, acc: 0.726562] [adversarial loss: 1.483962, acc: 0.140625]
# 35305: [discriminator loss: 0.495847, acc: 0.757812] [adversarial loss: 1.131277, acc: 0.296875]
# 35306: [discriminator loss: 0.512645, acc: 0.726562] [adversarial loss: 1.852892, acc: 0.078125]
# 35307: [discriminator loss: 0.592433, acc: 0.695312] [adversarial loss: 0.720855, acc: 0.640625]
# 35308: [discriminator loss: 0.555015, acc: 0.679688] [adversarial loss: 2.073032, acc: 0.046875]
# 35309: [discriminator loss: 0.565579, acc: 0.695312] [adversarial loss: 0.900732, acc: 0.500000]
# 35310: [discriminator loss: 0.578693, acc: 0.656250] [adversarial loss: 1.878200, acc: 0.125000]
# 35311: [discriminator loss: 0.510667, acc: 0.718750] [adversarial loss: 1.006919, acc: 0.328125]
# 35312: [discriminator loss: 0.468016, acc: 0.757812] [adversarial loss: 1.429252, acc: 0.250000]
# 35313: [discriminator loss: 0.533606, acc: 0.750000] [adversarial loss: 1.119843, acc: 0.234375]
# 35314: [discriminator loss: 0.476067, acc: 0.781250] [adversarial loss: 1.575685, acc: 0.156250]
# 35315: [discriminator loss: 0.424936, acc: 0.804688] [adversarial loss: 1.256846, acc: 0.218750]
# 35316: [discriminator loss: 0.446913, acc: 0.796875] [adversarial loss: 1.447789, acc: 0.187500]
# 35317: [discriminator loss: 0.508007, acc: 0.726562] [adversarial loss: 1.265779, acc: 0.250000]
# 35318: [discriminator loss: 0.520004, acc: 0.710938] [adversarial loss: 1.009748, acc: 0.343750]
# 35319: [discriminator loss: 0.450308, acc: 0.796875] [adversarial loss: 1.657918, acc: 0.109375]
# 35320: [discriminator loss: 0.476479, acc: 0.750000] [adversarial loss: 1.420426, acc: 0.187500]
# 35321: [discriminator loss: 0.534379, acc: 0.757812] [adversarial loss: 1.335379, acc: 0.281250]
# 35322: [discriminator loss: 0.483782, acc: 0.773438] [adversarial loss: 1.206612, acc: 0.375000]
# 35323: [discriminator loss: 0.514259, acc: 0.710938] [adversarial loss: 1.321259, acc: 0.218750]
# 35324: [discriminator loss: 0.496243, acc: 0.773438] [adversarial loss: 1.468440, acc: 0.187500]
# 35325: [discriminator loss: 0.541037, acc: 0.726562] [adversarial loss: 0.854226, acc: 0.453125]
# 35326: [discriminator loss: 0.554212, acc: 0.750000] [adversarial loss: 1.725222, acc: 0.140625]
# 35327: [discriminator loss: 0.503186, acc: 0.742188] [adversarial loss: 0.972658, acc: 0.437500]
# 35328: [discriminator loss: 0.597078, acc: 0.695312] [adversarial loss: 1.487685, acc: 0.156250]
# 35329: [discriminator loss: 0.469591, acc: 0.820312] [adversarial loss: 1.176392, acc: 0.156250]
# 35330: [discriminator loss: 0.458315, acc: 0.734375] [adversarial loss: 1.437999, acc: 0.171875]
# 35331: [discriminator loss: 0.572613, acc: 0.703125] [adversarial loss: 1.323052, acc: 0.234375]
# 35332: [discriminator loss: 0.518554, acc: 0.734375] [adversarial loss: 1.690449, acc: 0.156250]
# 35333: [discriminator loss: 0.570963, acc: 0.710938] [adversarial loss: 1.352062, acc: 0.156250]
# 35334: [discriminator loss: 0.480256, acc: 0.773438] [adversarial loss: 1.379964, acc: 0.156250]
# 35335: [discriminator loss: 0.468677, acc: 0.726562] [adversarial loss: 1.285396, acc: 0.250000]
# 35336: [discriminator loss: 0.496872, acc: 0.734375] [adversarial loss: 1.647781, acc: 0.125000]
# 35337: [discriminator loss: 0.557382, acc: 0.664062] [adversarial loss: 1.018612, acc: 0.312500]
# 35338: [discriminator loss: 0.561796, acc: 0.710938] [adversarial loss: 1.509926, acc: 0.171875]
# 35339: [discriminator loss: 0.507084, acc: 0.750000] [adversarial loss: 1.212454, acc: 0.281250]
# 35340: [discriminator loss: 0.507509, acc: 0.757812] [adversarial loss: 1.618745, acc: 0.156250]
# 35341: [discriminator loss: 0.468429, acc: 0.781250] [adversarial loss: 1.150769, acc: 0.312500]
# 35342: [discriminator loss: 0.498850, acc: 0.734375] [adversarial loss: 1.280233, acc: 0.265625]
# 35343: [discriminator loss: 0.516220, acc: 0.757812] [adversarial loss: 1.001704, acc: 0.406250]
# 35344: [discriminator loss: 0.493177, acc: 0.703125] [adversarial loss: 1.367816, acc: 0.218750]
# 35345: [discriminator loss: 0.503351, acc: 0.773438] [adversarial loss: 1.110402, acc: 0.343750]
# 35346: [discriminator loss: 0.492015, acc: 0.789062] [adversarial loss: 1.463481, acc: 0.203125]
# 35347: [discriminator loss: 0.500088, acc: 0.757812] [adversarial loss: 0.860810, acc: 0.421875]
# 35348: [discriminator loss: 0.557192, acc: 0.734375] [adversarial loss: 1.923436, acc: 0.125000]
# 35349: [discriminator loss: 0.495337, acc: 0.718750] [adversarial loss: 1.160858, acc: 0.343750]
# 35350: [discriminator loss: 0.513313, acc: 0.718750] [adversarial loss: 1.803542, acc: 0.078125]
# 35351: [discriminator loss: 0.613581, acc: 0.648438] [adversarial loss: 0.998641, acc: 0.312500]
# 35352: [discriminator loss: 0.508944, acc: 0.734375] [adversarial loss: 1.593361, acc: 0.125000]
# 35353: [discriminator loss: 0.534228, acc: 0.750000] [adversarial loss: 1.059704, acc: 0.390625]
# 35354: [discriminator loss: 0.566681, acc: 0.703125] [adversarial loss: 1.144961, acc: 0.343750]
# 35355: [discriminator loss: 0.583126, acc: 0.703125] [adversarial loss: 1.206313, acc: 0.171875]
# 35356: [discriminator loss: 0.483083, acc: 0.703125] [adversarial loss: 1.332374, acc: 0.218750]
# 35357: [discriminator loss: 0.549984, acc: 0.695312] [adversarial loss: 1.208176, acc: 0.281250]
# 35358: [discriminator loss: 0.521355, acc: 0.773438] [adversarial loss: 1.358192, acc: 0.281250]
# 35359: [discriminator loss: 0.506526, acc: 0.734375] [adversarial loss: 1.398253, acc: 0.218750]
# 35360: [discriminator loss: 0.519068, acc: 0.765625] [adversarial loss: 1.282172, acc: 0.281250]
# 35361: [discriminator loss: 0.594797, acc: 0.679688] [adversarial loss: 1.357278, acc: 0.234375]
# 35362: [discriminator loss: 0.523406, acc: 0.757812] [adversarial loss: 1.425373, acc: 0.171875]
# 35363: [discriminator loss: 0.471482, acc: 0.789062] [adversarial loss: 1.192860, acc: 0.250000]
# 35364: [discriminator loss: 0.528561, acc: 0.710938] [adversarial loss: 1.759601, acc: 0.140625]
# 35365: [discriminator loss: 0.569571, acc: 0.703125] [adversarial loss: 0.801353, acc: 0.515625]
# 35366: [discriminator loss: 0.557215, acc: 0.695312] [adversarial loss: 1.950561, acc: 0.062500]
# 35367: [discriminator loss: 0.514035, acc: 0.734375] [adversarial loss: 1.090926, acc: 0.359375]
# 35368: [discriminator loss: 0.612060, acc: 0.703125] [adversarial loss: 1.564834, acc: 0.109375]
# 35369: [discriminator loss: 0.542239, acc: 0.687500] [adversarial loss: 1.140526, acc: 0.312500]
# 35370: [discriminator loss: 0.444202, acc: 0.804688] [adversarial loss: 1.464154, acc: 0.187500]
# 35371: [discriminator loss: 0.545271, acc: 0.718750] [adversarial loss: 1.490803, acc: 0.218750]
# 35372: [discriminator loss: 0.480312, acc: 0.781250] [adversarial loss: 1.289703, acc: 0.218750]
# 35373: [discriminator loss: 0.446662, acc: 0.781250] [adversarial loss: 1.200749, acc: 0.203125]
# 35374: [discriminator loss: 0.531225, acc: 0.750000] [adversarial loss: 1.482032, acc: 0.203125]
# 35375: [discriminator loss: 0.502790, acc: 0.726562] [adversarial loss: 0.872387, acc: 0.437500]
# 35376: [discriminator loss: 0.513512, acc: 0.750000] [adversarial loss: 1.905178, acc: 0.078125]
# 35377: [discriminator loss: 0.509196, acc: 0.718750] [adversarial loss: 1.260155, acc: 0.265625]
# 35378: [discriminator loss: 0.525477, acc: 0.718750] [adversarial loss: 1.534237, acc: 0.156250]
# 35379: [discriminator loss: 0.585401, acc: 0.664062] [adversarial loss: 1.109991, acc: 0.265625]
# 35380: [discriminator loss: 0.545634, acc: 0.703125] [adversarial loss: 1.569261, acc: 0.218750]
# 35381: [discriminator loss: 0.583696, acc: 0.687500] [adversarial loss: 0.916011, acc: 0.406250]
# 35382: [discriminator loss: 0.504616, acc: 0.773438] [adversarial loss: 1.455251, acc: 0.203125]
# 35383: [discriminator loss: 0.552430, acc: 0.734375] [adversarial loss: 1.418471, acc: 0.156250]
# 35384: [discriminator loss: 0.487327, acc: 0.734375] [adversarial loss: 0.913899, acc: 0.437500]
# 35385: [discriminator loss: 0.560740, acc: 0.703125] [adversarial loss: 1.429267, acc: 0.140625]
# 35386: [discriminator loss: 0.444209, acc: 0.750000] [adversarial loss: 1.149667, acc: 0.296875]
# 35387: [discriminator loss: 0.563296, acc: 0.726562] [adversarial loss: 1.420017, acc: 0.171875]
# 35388: [discriminator loss: 0.515557, acc: 0.804688] [adversarial loss: 1.184042, acc: 0.296875]
# 35389: [discriminator loss: 0.526045, acc: 0.718750] [adversarial loss: 1.117325, acc: 0.265625]
# 35390: [discriminator loss: 0.491989, acc: 0.750000] [adversarial loss: 1.079000, acc: 0.328125]
# 35391: [discriminator loss: 0.564390, acc: 0.726562] [adversarial loss: 1.345457, acc: 0.234375]
# 35392: [discriminator loss: 0.468815, acc: 0.773438] [adversarial loss: 1.406654, acc: 0.265625]
# 35393: [discriminator loss: 0.502237, acc: 0.757812] [adversarial loss: 1.275572, acc: 0.265625]
# 35394: [discriminator loss: 0.555891, acc: 0.726562] [adversarial loss: 1.549355, acc: 0.156250]
# 35395: [discriminator loss: 0.512684, acc: 0.765625] [adversarial loss: 0.995187, acc: 0.468750]
# 35396: [discriminator loss: 0.529325, acc: 0.750000] [adversarial loss: 1.945538, acc: 0.093750]
# 35397: [discriminator loss: 0.554895, acc: 0.703125] [adversarial loss: 0.737144, acc: 0.531250]
# 35398: [discriminator loss: 0.623574, acc: 0.703125] [adversarial loss: 2.230256, acc: 0.062500]
# 35399: [discriminator loss: 0.662244, acc: 0.656250] [adversarial loss: 0.926852, acc: 0.453125]
# 35400: [discriminator loss: 0.501531, acc: 0.789062] [adversarial loss: 1.584895, acc: 0.125000]
# 35401: [discriminator loss: 0.562307, acc: 0.703125] [adversarial loss: 1.004487, acc: 0.343750]
# 35402: [discriminator loss: 0.558396, acc: 0.679688] [adversarial loss: 1.540134, acc: 0.140625]
# 35403: [discriminator loss: 0.579235, acc: 0.656250] [adversarial loss: 1.052849, acc: 0.359375]
# 35404: [discriminator loss: 0.565254, acc: 0.734375] [adversarial loss: 1.432612, acc: 0.156250]
# 35405: [discriminator loss: 0.564506, acc: 0.664062] [adversarial loss: 1.076203, acc: 0.328125]
# 35406: [discriminator loss: 0.464293, acc: 0.789062] [adversarial loss: 1.136236, acc: 0.250000]
# 35407: [discriminator loss: 0.480099, acc: 0.765625] [adversarial loss: 1.155613, acc: 0.312500]
# 35408: [discriminator loss: 0.494634, acc: 0.757812] [adversarial loss: 1.376734, acc: 0.171875]
# 35409: [discriminator loss: 0.507516, acc: 0.781250] [adversarial loss: 1.275567, acc: 0.296875]
# 35410: [discriminator loss: 0.460407, acc: 0.757812] [adversarial loss: 1.404619, acc: 0.140625]
# 35411: [discriminator loss: 0.547999, acc: 0.757812] [adversarial loss: 1.137332, acc: 0.328125]
# 35412: [discriminator loss: 0.464205, acc: 0.828125] [adversarial loss: 1.596345, acc: 0.125000]
# 35413: [discriminator loss: 0.525675, acc: 0.671875] [adversarial loss: 1.162434, acc: 0.312500]
# 35414: [discriminator loss: 0.488330, acc: 0.726562] [adversarial loss: 1.264652, acc: 0.234375]
# 35415: [discriminator loss: 0.533192, acc: 0.710938] [adversarial loss: 1.188507, acc: 0.296875]
# 35416: [discriminator loss: 0.566554, acc: 0.718750] [adversarial loss: 1.449836, acc: 0.171875]
# 35417: [discriminator loss: 0.574125, acc: 0.671875] [adversarial loss: 1.034531, acc: 0.343750]
# 35418: [discriminator loss: 0.531329, acc: 0.750000] [adversarial loss: 1.714000, acc: 0.078125]
# 35419: [discriminator loss: 0.583432, acc: 0.703125] [adversarial loss: 0.759448, acc: 0.562500]
# 35420: [discriminator loss: 0.596907, acc: 0.679688] [adversarial loss: 1.866650, acc: 0.109375]
# 35421: [discriminator loss: 0.514306, acc: 0.757812] [adversarial loss: 1.154718, acc: 0.281250]
# 35422: [discriminator loss: 0.530077, acc: 0.726562] [adversarial loss: 1.415623, acc: 0.156250]
# 35423: [discriminator loss: 0.498594, acc: 0.765625] [adversarial loss: 0.865166, acc: 0.484375]
# 35424: [discriminator loss: 0.594854, acc: 0.648438] [adversarial loss: 1.554786, acc: 0.203125]
# 35425: [discriminator loss: 0.523488, acc: 0.710938] [adversarial loss: 1.112872, acc: 0.343750]
# 35426: [discriminator loss: 0.511342, acc: 0.726562] [adversarial loss: 1.359434, acc: 0.109375]
# 35427: [discriminator loss: 0.568842, acc: 0.671875] [adversarial loss: 1.072741, acc: 0.265625]
# 35428: [discriminator loss: 0.543272, acc: 0.726562] [adversarial loss: 1.723175, acc: 0.140625]
# 35429: [discriminator loss: 0.524086, acc: 0.718750] [adversarial loss: 1.230094, acc: 0.312500]
# 35430: [discriminator loss: 0.450048, acc: 0.804688] [adversarial loss: 1.181997, acc: 0.343750]
# 35431: [discriminator loss: 0.481481, acc: 0.773438] [adversarial loss: 1.080245, acc: 0.390625]
# 35432: [discriminator loss: 0.518818, acc: 0.726562] [adversarial loss: 1.151376, acc: 0.265625]
# 35433: [discriminator loss: 0.486024, acc: 0.742188] [adversarial loss: 1.632049, acc: 0.156250]
# 35434: [discriminator loss: 0.528214, acc: 0.742188] [adversarial loss: 0.920855, acc: 0.515625]
# 35435: [discriminator loss: 0.519092, acc: 0.734375] [adversarial loss: 1.961129, acc: 0.062500]
# 35436: [discriminator loss: 0.541952, acc: 0.750000] [adversarial loss: 0.916245, acc: 0.390625]
# 35437: [discriminator loss: 0.512579, acc: 0.757812] [adversarial loss: 1.860451, acc: 0.125000]
# 35438: [discriminator loss: 0.573153, acc: 0.710938] [adversarial loss: 0.965620, acc: 0.375000]
# 35439: [discriminator loss: 0.546805, acc: 0.718750] [adversarial loss: 1.596194, acc: 0.140625]
# 35440: [discriminator loss: 0.488602, acc: 0.742188] [adversarial loss: 0.998046, acc: 0.265625]
# 35441: [discriminator loss: 0.505497, acc: 0.726562] [adversarial loss: 1.516441, acc: 0.187500]
# 35442: [discriminator loss: 0.476154, acc: 0.718750] [adversarial loss: 1.184304, acc: 0.328125]
# 35443: [discriminator loss: 0.551210, acc: 0.695312] [adversarial loss: 1.521437, acc: 0.171875]
# 35444: [discriminator loss: 0.557421, acc: 0.734375] [adversarial loss: 1.012325, acc: 0.500000]
# 35445: [discriminator loss: 0.498733, acc: 0.804688] [adversarial loss: 1.607958, acc: 0.078125]
# 35446: [discriminator loss: 0.616085, acc: 0.671875] [adversarial loss: 1.083643, acc: 0.406250]
# 35447: [discriminator loss: 0.560214, acc: 0.703125] [adversarial loss: 1.469759, acc: 0.125000]
# 35448: [discriminator loss: 0.573764, acc: 0.710938] [adversarial loss: 1.282282, acc: 0.328125]
# 35449: [discriminator loss: 0.598118, acc: 0.695312] [adversarial loss: 1.121104, acc: 0.281250]
# 35450: [discriminator loss: 0.493717, acc: 0.765625] [adversarial loss: 1.221599, acc: 0.234375]
# 35451: [discriminator loss: 0.520901, acc: 0.679688] [adversarial loss: 1.258874, acc: 0.203125]
# 35452: [discriminator loss: 0.607920, acc: 0.640625] [adversarial loss: 1.433641, acc: 0.218750]
# 35453: [discriminator loss: 0.521779, acc: 0.734375] [adversarial loss: 1.424268, acc: 0.171875]
# 35454: [discriminator loss: 0.514822, acc: 0.734375] [adversarial loss: 1.619108, acc: 0.125000]
# 35455: [discriminator loss: 0.499090, acc: 0.750000] [adversarial loss: 1.158612, acc: 0.375000]
# 35456: [discriminator loss: 0.528654, acc: 0.726562] [adversarial loss: 1.666844, acc: 0.171875]
# 35457: [discriminator loss: 0.547650, acc: 0.726562] [adversarial loss: 1.130064, acc: 0.281250]
# 35458: [discriminator loss: 0.450431, acc: 0.828125] [adversarial loss: 1.393157, acc: 0.109375]
# 35459: [discriminator loss: 0.494425, acc: 0.765625] [adversarial loss: 1.071014, acc: 0.406250]
# 35460: [discriminator loss: 0.486380, acc: 0.789062] [adversarial loss: 1.733265, acc: 0.156250]
# 35461: [discriminator loss: 0.521353, acc: 0.750000] [adversarial loss: 1.074737, acc: 0.421875]
# 35462: [discriminator loss: 0.571627, acc: 0.679688] [adversarial loss: 1.382365, acc: 0.093750]
# 35463: [discriminator loss: 0.475083, acc: 0.773438] [adversarial loss: 1.092780, acc: 0.359375]
# 35464: [discriminator loss: 0.540322, acc: 0.718750] [adversarial loss: 1.513951, acc: 0.156250]
# 35465: [discriminator loss: 0.512983, acc: 0.734375] [adversarial loss: 1.078748, acc: 0.390625]
# 35466: [discriminator loss: 0.504207, acc: 0.750000] [adversarial loss: 1.518627, acc: 0.156250]
# 35467: [discriminator loss: 0.504222, acc: 0.726562] [adversarial loss: 1.253356, acc: 0.281250]
# 35468: [discriminator loss: 0.496671, acc: 0.726562] [adversarial loss: 1.468335, acc: 0.156250]
# 35469: [discriminator loss: 0.527017, acc: 0.765625] [adversarial loss: 0.997969, acc: 0.359375]
# 35470: [discriminator loss: 0.537680, acc: 0.710938] [adversarial loss: 1.777233, acc: 0.078125]
# 35471: [discriminator loss: 0.451295, acc: 0.781250] [adversarial loss: 1.056969, acc: 0.328125]
# 35472: [discriminator loss: 0.524336, acc: 0.773438] [adversarial loss: 1.684345, acc: 0.125000]
# 35473: [discriminator loss: 0.472388, acc: 0.718750] [adversarial loss: 0.966910, acc: 0.406250]
# 35474: [discriminator loss: 0.489403, acc: 0.742188] [adversarial loss: 1.571809, acc: 0.093750]
# 35475: [discriminator loss: 0.572847, acc: 0.687500] [adversarial loss: 0.852940, acc: 0.468750]
# 35476: [discriminator loss: 0.580275, acc: 0.726562] [adversarial loss: 1.488662, acc: 0.203125]
# 35477: [discriminator loss: 0.616876, acc: 0.695312] [adversarial loss: 1.379383, acc: 0.156250]
# 35478: [discriminator loss: 0.530882, acc: 0.789062] [adversarial loss: 1.166037, acc: 0.359375]
# 35479: [discriminator loss: 0.498932, acc: 0.750000] [adversarial loss: 1.421873, acc: 0.218750]
# 35480: [discriminator loss: 0.534345, acc: 0.726562] [adversarial loss: 1.157240, acc: 0.312500]
# 35481: [discriminator loss: 0.530776, acc: 0.726562] [adversarial loss: 1.527736, acc: 0.156250]
# 35482: [discriminator loss: 0.591018, acc: 0.632812] [adversarial loss: 0.954819, acc: 0.421875]
# 35483: [discriminator loss: 0.530962, acc: 0.750000] [adversarial loss: 1.412090, acc: 0.218750]
# 35484: [discriminator loss: 0.576985, acc: 0.687500] [adversarial loss: 1.281874, acc: 0.281250]
# 35485: [discriminator loss: 0.505944, acc: 0.757812] [adversarial loss: 1.374979, acc: 0.203125]
# 35486: [discriminator loss: 0.429271, acc: 0.812500] [adversarial loss: 1.236440, acc: 0.203125]
# 35487: [discriminator loss: 0.504116, acc: 0.781250] [adversarial loss: 1.500060, acc: 0.187500]
# 35488: [discriminator loss: 0.546826, acc: 0.742188] [adversarial loss: 1.012595, acc: 0.406250]
# 35489: [discriminator loss: 0.541343, acc: 0.742188] [adversarial loss: 1.655339, acc: 0.062500]
# 35490: [discriminator loss: 0.466746, acc: 0.804688] [adversarial loss: 0.977584, acc: 0.406250]
# 35491: [discriminator loss: 0.550852, acc: 0.726562] [adversarial loss: 1.819931, acc: 0.062500]
# 35492: [discriminator loss: 0.535787, acc: 0.710938] [adversarial loss: 0.827950, acc: 0.562500]
# 35493: [discriminator loss: 0.556938, acc: 0.710938] [adversarial loss: 1.910206, acc: 0.062500]
# ...
# 39836: [discriminator loss: 0.517155, acc: 0.734375] [adversarial loss: 1.416299, acc: 0.203125]
# 39837: [discriminator loss: 0.508791, acc: 0.742188] [adversarial loss: 1.532566, acc: 0.250000]
# 39838: [discriminator loss: 0.521491, acc: 0.734375] [adversarial loss: 1.374785, acc: 0.312500]
# 39839: [discriminator loss: 0.540248, acc: 0.726562] [adversarial loss: 1.155692, acc: 0.312500]
# 39840: [discriminator loss: 0.480572, acc: 0.757812] [adversarial loss: 1.003159, acc: 0.359375]
# 39841: [discriminator loss: 0.535130, acc: 0.757812] [adversarial loss: 1.402857, acc: 0.187500]
# 39842: [discriminator loss: 0.505794, acc: 0.750000] [adversarial loss: 1.267328, acc: 0.296875]
# 39843: [discriminator loss: 0.454134, acc: 0.765625] [adversarial loss: 1.784386, acc: 0.125000]
# 39844: [discriminator loss: 0.613361, acc: 0.679688] [adversarial loss: 1.220840, acc: 0.281250]
# 39845: [discriminator loss: 0.502365, acc: 0.726562] [adversarial loss: 1.482683, acc: 0.203125]
# 39846: [discriminator loss: 0.491109, acc: 0.781250] [adversarial loss: 1.020161, acc: 0.484375]
# 39847: [discriminator loss: 0.472305, acc: 0.757812] [adversarial loss: 1.582234, acc: 0.140625]
# 39848: [discriminator loss: 0.545727, acc: 0.718750] [adversarial loss: 0.787097, acc: 0.562500]
# 39849: [discriminator loss: 0.556945, acc: 0.703125] [adversarial loss: 1.688755, acc: 0.156250]
# 39850: [discriminator loss: 0.634336, acc: 0.671875] [adversarial loss: 1.081553, acc: 0.390625]
# 39851: [discriminator loss: 0.475823, acc: 0.750000] [adversarial loss: 1.650120, acc: 0.187500]
# 39852: [discriminator loss: 0.544509, acc: 0.718750] [adversarial loss: 1.265519, acc: 0.234375]
# 39853: [discriminator loss: 0.526143, acc: 0.703125] [adversarial loss: 1.390193, acc: 0.234375]
# 39854: [discriminator loss: 0.512648, acc: 0.734375] [adversarial loss: 1.094332, acc: 0.281250]
# 39855: [discriminator loss: 0.515872, acc: 0.750000] [adversarial loss: 1.444972, acc: 0.125000]
# 39856: [discriminator loss: 0.565014, acc: 0.664062] [adversarial loss: 0.982219, acc: 0.390625]
# 39857: [discriminator loss: 0.522940, acc: 0.718750] [adversarial loss: 1.354217, acc: 0.203125]
# 39858: [discriminator loss: 0.527305, acc: 0.718750] [adversarial loss: 1.189919, acc: 0.312500]
# 39859: [discriminator loss: 0.545864, acc: 0.742188] [adversarial loss: 1.696794, acc: 0.109375]
# 39860: [discriminator loss: 0.500666, acc: 0.726562] [adversarial loss: 1.186021, acc: 0.281250]
# 39861: [discriminator loss: 0.425854, acc: 0.734375] [adversarial loss: 1.392754, acc: 0.250000]
# 39862: [discriminator loss: 0.482738, acc: 0.718750] [adversarial loss: 1.354828, acc: 0.250000]
# 39863: [discriminator loss: 0.556092, acc: 0.718750] [adversarial loss: 1.599160, acc: 0.156250]
# 39864: [discriminator loss: 0.566524, acc: 0.687500] [adversarial loss: 1.195801, acc: 0.406250]
# 39865: [discriminator loss: 0.596233, acc: 0.687500] [adversarial loss: 1.853710, acc: 0.078125]
# 39866: [discriminator loss: 0.507799, acc: 0.703125] [adversarial loss: 1.144580, acc: 0.375000]
# 39867: [discriminator loss: 0.507664, acc: 0.773438] [adversarial loss: 1.280308, acc: 0.234375]
# 39868: [discriminator loss: 0.458942, acc: 0.726562] [adversarial loss: 1.369741, acc: 0.171875]
# 39869: [discriminator loss: 0.513729, acc: 0.765625] [adversarial loss: 1.044039, acc: 0.375000]
# 39870: [discriminator loss: 0.536789, acc: 0.734375] [adversarial loss: 1.860469, acc: 0.125000]
# 39871: [discriminator loss: 0.549448, acc: 0.726562] [adversarial loss: 1.456045, acc: 0.156250]
# 39872: [discriminator loss: 0.467024, acc: 0.757812] [adversarial loss: 1.238890, acc: 0.296875]
# 39873: [discriminator loss: 0.532264, acc: 0.726562] [adversarial loss: 1.257279, acc: 0.296875]
# 39874: [discriminator loss: 0.555245, acc: 0.664062] [adversarial loss: 1.398570, acc: 0.312500]
# 39875: [discriminator loss: 0.522425, acc: 0.742188] [adversarial loss: 0.991084, acc: 0.421875]
# 39876: [discriminator loss: 0.525740, acc: 0.718750] [adversarial loss: 1.816675, acc: 0.046875]
# 39877: [discriminator loss: 0.544131, acc: 0.710938] [adversarial loss: 1.049718, acc: 0.343750]
# 39878: [discriminator loss: 0.516215, acc: 0.757812] [adversarial loss: 1.633336, acc: 0.203125]
# 39879: [discriminator loss: 0.541757, acc: 0.718750] [adversarial loss: 1.040613, acc: 0.453125]
# 39880: [discriminator loss: 0.550007, acc: 0.726562] [adversarial loss: 1.486978, acc: 0.234375]
# 39881: [discriminator loss: 0.532635, acc: 0.703125] [adversarial loss: 1.259641, acc: 0.281250]
# 39882: [discriminator loss: 0.473879, acc: 0.804688] [adversarial loss: 1.631428, acc: 0.171875]
# 39883: [discriminator loss: 0.512650, acc: 0.742188] [adversarial loss: 1.230517, acc: 0.296875]
# 39884: [discriminator loss: 0.501567, acc: 0.757812] [adversarial loss: 1.716562, acc: 0.093750]
# 39885: [discriminator loss: 0.522595, acc: 0.734375] [adversarial loss: 0.904224, acc: 0.390625]
# 39886: [discriminator loss: 0.576559, acc: 0.687500] [adversarial loss: 1.753602, acc: 0.171875]
# 39887: [discriminator loss: 0.479521, acc: 0.726562] [adversarial loss: 1.457020, acc: 0.218750]
# 39888: [discriminator loss: 0.478977, acc: 0.773438] [adversarial loss: 1.498720, acc: 0.171875]
# 39889: [discriminator loss: 0.473775, acc: 0.765625] [adversarial loss: 1.072896, acc: 0.406250]
# 39890: [discriminator loss: 0.478780, acc: 0.796875] [adversarial loss: 1.795208, acc: 0.156250]
# 39891: [discriminator loss: 0.487592, acc: 0.750000] [adversarial loss: 1.110989, acc: 0.375000]
# 39892: [discriminator loss: 0.659348, acc: 0.726562] [adversarial loss: 1.835781, acc: 0.125000]
# 39893: [discriminator loss: 0.571831, acc: 0.726562] [adversarial loss: 1.099658, acc: 0.328125]
# 39894: [discriminator loss: 0.496688, acc: 0.742188] [adversarial loss: 1.476341, acc: 0.218750]
# 39895: [discriminator loss: 0.566891, acc: 0.710938] [adversarial loss: 0.835250, acc: 0.484375]
# 39896: [discriminator loss: 0.508830, acc: 0.742188] [adversarial loss: 1.714464, acc: 0.203125]
# 39897: [discriminator loss: 0.539246, acc: 0.726562] [adversarial loss: 1.150074, acc: 0.343750]
# 39898: [discriminator loss: 0.501219, acc: 0.757812] [adversarial loss: 1.565714, acc: 0.156250]
# 39899: [discriminator loss: 0.430589, acc: 0.820312] [adversarial loss: 1.087053, acc: 0.453125]
# 39900: [discriminator loss: 0.534519, acc: 0.656250] [adversarial loss: 1.606151, acc: 0.125000]
# 39901: [discriminator loss: 0.498448, acc: 0.742188] [adversarial loss: 1.202201, acc: 0.312500]
# 39902: [discriminator loss: 0.550125, acc: 0.726562] [adversarial loss: 1.494352, acc: 0.187500]
# 39903: [discriminator loss: 0.549160, acc: 0.710938] [adversarial loss: 1.059072, acc: 0.359375]
# 39904: [discriminator loss: 0.479283, acc: 0.796875] [adversarial loss: 1.410178, acc: 0.250000]
# 39905: [discriminator loss: 0.498216, acc: 0.765625] [adversarial loss: 1.257802, acc: 0.234375]
# 39906: [discriminator loss: 0.615371, acc: 0.671875] [adversarial loss: 1.699614, acc: 0.125000]
# 39907: [discriminator loss: 0.559185, acc: 0.671875] [adversarial loss: 0.899815, acc: 0.546875]
# 39908: [discriminator loss: 0.547034, acc: 0.687500] [adversarial loss: 1.811273, acc: 0.125000]
# 39909: [discriminator loss: 0.559869, acc: 0.703125] [adversarial loss: 1.056974, acc: 0.343750]
# 39910: [discriminator loss: 0.518779, acc: 0.726562] [adversarial loss: 1.698648, acc: 0.140625]
# 39911: [discriminator loss: 0.644208, acc: 0.632812] [adversarial loss: 1.208619, acc: 0.328125]
# 39912: [discriminator loss: 0.543021, acc: 0.718750] [adversarial loss: 1.454040, acc: 0.125000]
# 39913: [discriminator loss: 0.451309, acc: 0.781250] [adversarial loss: 0.944533, acc: 0.328125]
# 39914: [discriminator loss: 0.501898, acc: 0.750000] [adversarial loss: 1.341420, acc: 0.250000]
# 39915: [discriminator loss: 0.489636, acc: 0.742188] [adversarial loss: 1.379378, acc: 0.234375]
# 39916: [discriminator loss: 0.586276, acc: 0.718750] [adversarial loss: 1.336171, acc: 0.156250]
# 39917: [discriminator loss: 0.509296, acc: 0.750000] [adversarial loss: 1.250608, acc: 0.281250]
# 39918: [discriminator loss: 0.499996, acc: 0.710938] [adversarial loss: 1.251917, acc: 0.265625]
# 39919: [discriminator loss: 0.523010, acc: 0.742188] [adversarial loss: 1.493730, acc: 0.125000]
# 39920: [discriminator loss: 0.520422, acc: 0.687500] [adversarial loss: 1.085390, acc: 0.375000]
# 39921: [discriminator loss: 0.514335, acc: 0.750000] [adversarial loss: 1.576042, acc: 0.062500]
# 39922: [discriminator loss: 0.437119, acc: 0.789062] [adversarial loss: 0.938860, acc: 0.484375]
# 39923: [discriminator loss: 0.538698, acc: 0.726562] [adversarial loss: 1.660362, acc: 0.171875]
# 39924: [discriminator loss: 0.495053, acc: 0.757812] [adversarial loss: 0.817537, acc: 0.515625]
# 39925: [discriminator loss: 0.562250, acc: 0.687500] [adversarial loss: 1.663956, acc: 0.093750]
# 39926: [discriminator loss: 0.509837, acc: 0.734375] [adversarial loss: 1.024033, acc: 0.406250]
# 39927: [discriminator loss: 0.511995, acc: 0.734375] [adversarial loss: 1.291934, acc: 0.203125]
# 39928: [discriminator loss: 0.456586, acc: 0.781250] [adversarial loss: 1.269914, acc: 0.250000]
# 39929: [discriminator loss: 0.489937, acc: 0.703125] [adversarial loss: 1.245536, acc: 0.250000]
# 39930: [discriminator loss: 0.480898, acc: 0.742188] [adversarial loss: 1.032372, acc: 0.343750]
# 39931: [discriminator loss: 0.592688, acc: 0.718750] [adversarial loss: 2.111793, acc: 0.078125]
# 39932: [discriminator loss: 0.533273, acc: 0.718750] [adversarial loss: 0.945669, acc: 0.375000]
# 39933: [discriminator loss: 0.437215, acc: 0.804688] [adversarial loss: 1.675117, acc: 0.125000]
# 39934: [discriminator loss: 0.529388, acc: 0.742188] [adversarial loss: 1.351234, acc: 0.265625]
# 39935: [discriminator loss: 0.437270, acc: 0.773438] [adversarial loss: 1.896506, acc: 0.062500]
# 39936: [discriminator loss: 0.461906, acc: 0.742188] [adversarial loss: 1.239066, acc: 0.234375]
# 39937: [discriminator loss: 0.478217, acc: 0.789062] [adversarial loss: 1.580207, acc: 0.140625]
# 39938: [discriminator loss: 0.489336, acc: 0.757812] [adversarial loss: 1.057988, acc: 0.390625]
# 39939: [discriminator loss: 0.415920, acc: 0.851562] [adversarial loss: 1.661138, acc: 0.125000]
# 39940: [discriminator loss: 0.520328, acc: 0.734375] [adversarial loss: 1.279357, acc: 0.218750]
# 39941: [discriminator loss: 0.571779, acc: 0.679688] [adversarial loss: 1.396986, acc: 0.218750]
# 39942: [discriminator loss: 0.522872, acc: 0.695312] [adversarial loss: 1.157145, acc: 0.234375]
# 39943: [discriminator loss: 0.547101, acc: 0.742188] [adversarial loss: 1.378160, acc: 0.234375]
# 39944: [discriminator loss: 0.427424, acc: 0.828125] [adversarial loss: 1.353671, acc: 0.218750]
# 39945: [discriminator loss: 0.542073, acc: 0.750000] [adversarial loss: 1.329813, acc: 0.125000]
# 39946: [discriminator loss: 0.542464, acc: 0.765625] [adversarial loss: 1.439063, acc: 0.078125]
# 39947: [discriminator loss: 0.501094, acc: 0.726562] [adversarial loss: 1.195129, acc: 0.281250]
# 39948: [discriminator loss: 0.478674, acc: 0.781250] [adversarial loss: 1.680371, acc: 0.078125]
# 39949: [discriminator loss: 0.556808, acc: 0.679688] [adversarial loss: 0.850051, acc: 0.562500]
# 39950: [discriminator loss: 0.530435, acc: 0.742188] [adversarial loss: 1.798224, acc: 0.109375]
# 39951: [discriminator loss: 0.520848, acc: 0.726562] [adversarial loss: 1.004945, acc: 0.359375]
# 39952: [discriminator loss: 0.494812, acc: 0.757812] [adversarial loss: 1.807331, acc: 0.062500]
# 39953: [discriminator loss: 0.518732, acc: 0.734375] [adversarial loss: 0.909672, acc: 0.484375]
# 39954: [discriminator loss: 0.558905, acc: 0.679688] [adversarial loss: 1.628289, acc: 0.187500]
# 39955: [discriminator loss: 0.467865, acc: 0.765625] [adversarial loss: 1.256415, acc: 0.250000]
# 39956: [discriminator loss: 0.539016, acc: 0.687500] [adversarial loss: 1.490398, acc: 0.218750]
# 39957: [discriminator loss: 0.452256, acc: 0.781250] [adversarial loss: 1.043658, acc: 0.359375]
# 39958: [discriminator loss: 0.388734, acc: 0.851562] [adversarial loss: 1.558472, acc: 0.125000]
# 39959: [discriminator loss: 0.533651, acc: 0.718750] [adversarial loss: 0.781857, acc: 0.453125]
# 39960: [discriminator loss: 0.503635, acc: 0.734375] [adversarial loss: 1.526733, acc: 0.140625]
# 39961: [discriminator loss: 0.444966, acc: 0.789062] [adversarial loss: 0.991489, acc: 0.390625]
# 39962: [discriminator loss: 0.479161, acc: 0.789062] [adversarial loss: 1.509864, acc: 0.187500]
# 39963: [discriminator loss: 0.481889, acc: 0.781250] [adversarial loss: 1.180614, acc: 0.343750]
# 39964: [discriminator loss: 0.496603, acc: 0.750000] [adversarial loss: 1.681177, acc: 0.062500]
# 39965: [discriminator loss: 0.496436, acc: 0.742188] [adversarial loss: 0.890397, acc: 0.500000]
# 39966: [discriminator loss: 0.517311, acc: 0.765625] [adversarial loss: 2.147133, acc: 0.093750]
# 39967: [discriminator loss: 0.587734, acc: 0.718750] [adversarial loss: 1.131035, acc: 0.296875]
# 39968: [discriminator loss: 0.510170, acc: 0.742188] [adversarial loss: 1.464003, acc: 0.187500]
# 39969: [discriminator loss: 0.496138, acc: 0.789062] [adversarial loss: 1.358727, acc: 0.203125]
# 39970: [discriminator loss: 0.492693, acc: 0.804688] [adversarial loss: 1.274181, acc: 0.250000]
# 39971: [discriminator loss: 0.512133, acc: 0.734375] [adversarial loss: 1.116702, acc: 0.343750]
# 39972: [discriminator loss: 0.542431, acc: 0.710938] [adversarial loss: 1.652941, acc: 0.156250]
# 39973: [discriminator loss: 0.518170, acc: 0.710938] [adversarial loss: 1.173752, acc: 0.312500]
# 39974: [discriminator loss: 0.571605, acc: 0.695312] [adversarial loss: 1.785825, acc: 0.093750]
# 39975: [discriminator loss: 0.576444, acc: 0.695312] [adversarial loss: 1.024923, acc: 0.421875]
# 39976: [discriminator loss: 0.542525, acc: 0.695312] [adversarial loss: 1.852560, acc: 0.078125]
# 39977: [discriminator loss: 0.509463, acc: 0.718750] [adversarial loss: 0.971489, acc: 0.390625]
# 39978: [discriminator loss: 0.573253, acc: 0.687500] [adversarial loss: 1.605797, acc: 0.125000]
# 39979: [discriminator loss: 0.556519, acc: 0.687500] [adversarial loss: 1.103381, acc: 0.375000]
# 39980: [discriminator loss: 0.504761, acc: 0.773438] [adversarial loss: 1.467679, acc: 0.234375]
# 39981: [discriminator loss: 0.601209, acc: 0.656250] [adversarial loss: 1.084947, acc: 0.343750]
# 39982: [discriminator loss: 0.523817, acc: 0.742188] [adversarial loss: 1.569143, acc: 0.125000]
# 39983: [discriminator loss: 0.530999, acc: 0.726562] [adversarial loss: 0.760555, acc: 0.593750]
# 39984: [discriminator loss: 0.469006, acc: 0.812500] [adversarial loss: 1.409185, acc: 0.109375]
# 39985: [discriminator loss: 0.493943, acc: 0.710938] [adversarial loss: 1.723493, acc: 0.093750]
# 39986: [discriminator loss: 0.582831, acc: 0.687500] [adversarial loss: 0.943003, acc: 0.375000]
# 39987: [discriminator loss: 0.588810, acc: 0.687500] [adversarial loss: 2.062990, acc: 0.109375]
# 39988: [discriminator loss: 0.581789, acc: 0.679688] [adversarial loss: 1.153644, acc: 0.343750]
# 39989: [discriminator loss: 0.505495, acc: 0.726562] [adversarial loss: 1.761713, acc: 0.109375]
# 39990: [discriminator loss: 0.564109, acc: 0.687500] [adversarial loss: 0.879970, acc: 0.406250]
# 39991: [discriminator loss: 0.486125, acc: 0.765625] [adversarial loss: 1.192305, acc: 0.296875]
# 39992: [discriminator loss: 0.444238, acc: 0.789062] [adversarial loss: 1.456718, acc: 0.250000]
# 39993: [discriminator loss: 0.494873, acc: 0.757812] [adversarial loss: 1.188209, acc: 0.296875]
# 39994: [discriminator loss: 0.448077, acc: 0.828125] [adversarial loss: 1.265311, acc: 0.265625]
# 39995: [discriminator loss: 0.482679, acc: 0.757812] [adversarial loss: 1.109673, acc: 0.265625]
# 39996: [discriminator loss: 0.546026, acc: 0.765625] [adversarial loss: 1.496211, acc: 0.187500]
# 39997: [discriminator loss: 0.590058, acc: 0.648438] [adversarial loss: 1.124327, acc: 0.375000]
# 39998: [discriminator loss: 0.546819, acc: 0.750000] [adversarial loss: 1.687380, acc: 0.093750]
# 39999: [discriminator loss: 0.487313, acc: 0.750000] [adversarial loss: 0.904959, acc: 0.453125]

# %%
parser = argparse.ArgumentParser()
help_ = "Load generator h5 model with trained weights"
parser.add_argument("-g", "--generator", help=help_)
args = parser.parse_args()
if args.generator:
    generator = load_model(args.generator)
    test_generator(generator)
else:
    build_and_train_models()
# Out:
# usage: ipykernel_launcher.py [-h] [-g GENERATOR]
# ipykernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-069fac8f-f114-488a-9b2e-d17095104737.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
